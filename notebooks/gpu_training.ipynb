# %% [markdown]
# # CRN Overlay Training on GPU
# This notebook provides a simple, interactive way to train the `OVERLAY_TD3` model for 3,000 episodes on a GPU. Run the cells below sequentially.

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -r ../requirements.txt
# Out:
# ERROR: Invalid requirement: 'w\x00a\x00n\x00d\x00b\x00': Expected semicolon (after name with no version specifier) or end
#     wandb
#      ^ (from line 14 of ../requirements.txt)

# %% [markdown]
# ## 2. Verify GPU Availability
# Ensure that PyTorch detects the CUDA-enabled GPU.

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
else:
    print("WARNING: No GPU detected! Training will be extremely slow.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torch
#       2 print(f"PyTorch version: {torch.__version__}")
#       3 print(f"CUDA available: {torch.cuda.is_available()}")
#       4 if torch.cuda.is_available():
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## 3. Run the Training Pipeline
# This will execute the main simulation for 3,000 episodes using Aditya's `OVERLAY_TD3` algorithm.

# %%
# !python ../main.py train --agent overlay --episodes 3000 --device cuda --save-best True --tensorboard True

# %% [markdown]
# ## 4. Visualize Results
# View the live training metrics (throughput, outage, power, etc.) via TensorBoard.

# %%
# %load_ext tensorboard
# %tensorboard --logdir ../experiments/runs/
